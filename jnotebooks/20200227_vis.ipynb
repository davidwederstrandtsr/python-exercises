# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
y =[5,2,3,4,5]

plt.plot(y)

# %%
#plot y = x^2

x = range(-4, 5)
y = [x**2 for x in x]

plt.plot(x, y, marker='x')

# %%
plt.hist(x, bins=len(x), edgecolor='black', facecolor='red')
# Out:
# (array([1., 1., 1., 1., 1., 1., 1., 1., 1.]),
#  array([-4.        , -3.11111111, -2.22222222, -1.33333333, -0.44444444,
#          0.44444444,  1.33333333,  2.22222222,  3.11111111,  4.        ]),
#  <a list of 9 Patch objects>)

# %% [markdown]
# ## Interactive Documentation in Jupyter Notebooks
#
# put your cursor within the parenthesis of a function call and press "Shift + Tab" to see the documentation
#
# plt? opens the help

# %%
x = ['data science', 'web dev']
y = [16, 7]
plt.bar(x, y, edgecolor='firebrick')
# plt.barh(y, x) horizontal
plt.ylabel('Avg Student Coolness')
plt.title('Avg Coolness by Codeup Program')
# Out:
# Text(0.5, 1.0, 'Avg Coolness by Codeup Program')

# %%
plt?
