# %%
filename = "data/import_exercises.py"

# %%
with open(filename, "r") as f:
    contents = f.readlines()

# %%
with open(filename, "r") as f:
    contents = f.readlines()
    for i, line in enumerate(contents, 1):
        print(i, ": ", line)
# Out:
# 1 :  #!/usr/bin/env python
#
# 2 :  # coding: utf-8
#
# 3 :
#
# 4 :  # 1. Import and test 3 of the functions from your functions exercise file.
#
# 5 :  #    Your functions exercise are not currently in a file with a name that can be easily imported.
#
# 6 :  #    Copy your functions exercise file and name the copy functions_exercises.py.
#
# 7 :
#
# 8 :  #    Import each function in a different way:
#
# 9 :  #         import the module and refer to the function with the . syntax
#
# 10 :  #         use from to import the function directly
#
# 11 :  #         use from and give the function a different name
#
# 12 :
#
# 13 :  import functions_exercises
#
# 14 :
#
# 15 :  assert functions_exercises.calculate_tip(10, 100) == 110
#
# 16 :  assert functions_exercises.calculate_tip(10, 110) != 110
#
# 17 :
#
# 18 :  from functions_exercises import handle_commas
#
# 19 :
#
# 20 :  assert handle_commas('1,111') == 1111
#
# 21 :  assert handle_commas('1,111') != 1110
#
# 22 :
#
# 23 :  from functions_exercises import get_letter_grade as glg
#
# 24 :
#
# 25 :  assert glg(86) == 'B'
#
# 26 :  assert glg(86) != 'A'
#
# 27 :
#
# 28 :  # For the following exercises, read about and use the itertools module from the standard library
#
# 29 :  # to help you solve the problem.
#
# 30 :
#
# 31 :  # 1. How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?
#
# 32 :
#
# 33 :  from itertools import product
#
# 34 :
#
# 35 :  list(product("abc", ('123')))
#
# 36 :
#
# 37 :  len(list(product("abc", ('123'))))
#
# 38 :
#
# 39 :
#
# 40 :  # 2. How many different ways can you combine two of the letters from "abcd"?
#
# 41 :  from itertools import permutations
#
# 42 :
#
# 43 :  list(permutations("abcd", 2))
#
# 44 :  len(list(permutations("abcd", 2)))
#
# 45 :
#
# 46 :  # Save this file as profiles.json inside of your exercises directory. Use the load function from the
#
# 47 :  # json module to open this file, it will produce a list of dictionaries. Using this data, write some
#
# 48 :  # code that calculates and outputs the following information:
#
# 49 :
#
# 50 :  from json import load
#
# 51 :
#
# 52 :  profiles = load(open("profiles.json"))
#
# 53 :
#
# 54 :
#
# 55 :  # Total number of users
#
# 56 :  len(profiles)
#
# 57 :
#
# 58 :
#
# 59 :  # Number of active users
#
# 60 :  len([profile for profile in profiles if profile['isActive'] == True])
#
# 61 :
#
# 62 :
#
# 63 :  # Number of inactive users
#
# 64 :  len([profile for profile in profiles if profile['isActive'] == False])
#
# 65 :
#
# 66 :
#
# 67 :  # Grand total of balances for all users
#
# 68 :  def float_convertor(num):
#
# 69 :      return float(num.replace(',','').replace('$',''))
#
# 70 :
#
# 71 :  profile_balances = [profile['balance'] for profile in profiles]
#
# 72 :  profile_balances
#
# 73 :
#
# 74 :  newlist = []
#
# 75 :
#
# 76 :  for profile in profile_balances:
#
# 77 :      newlist.append(float_convertor(profile))
#
# 78 :  newlist
#
# 79 :
#
# 80 :  total = sum(newlist)
#
# 81 :
#
# 82 :
#
# 83 :  # Average balance per user
#
# 84 :  total / len(newlist)
#
# 85 :
#
# 86 :
#
# 87 :  # User with the lowest balance
#
# 88 :  min(newlist)
#
# 89 :
#
# 90 :  minlist = []
#
# 91 :  minlist = [x for x in range(len(newlist)) if newlist[x] == min(newlist)]
#
# 92 :  minlist
#
# 93 :
#
# 94 :  profiles[minlist[0]]['name'], profiles[minlist[0]]['balance']
#
# 95 :
#
# 96 :
#
# 97 :  # User with the highest balance
#
# 98 :  maxlist = []
#
# 99 :  maxlist = [x for x in range(len(newlist)) if newlist[x] == max(newlist)]
#
# 100 :  maxlist
#
# 101 :
#
# 102 :  profiles[maxlist[0]]['name'], profiles[maxlist[0]]['balance']
#
# 103 :
#
# 104 :
#
# 105 :  # Most common favorite fruit
#
# 106 :  fruitlist = [profile['favoriteFruit'] for profile in profiles]
#
# 107 :  fruitlist
#
# 108 :
#
# 109 :  fruit_count = [fruitlist.count(fruit) for fruit in fruitlist]
#
# 110 :  fruit_count
#
# 111 :
#
# 112 :  newfruitlist = list(zip(fruit_count, fruitlist))
#
# 113 :  newfruitlist
#
# 114 :
#
# 115 :  max(newfruitlist)
#
# 116 :
#
# 117 :
#
# 118 :  # Least most common favorite fruit
#
# 119 :  min(newfruitlist)
#
# 120 :
#
# 121 :
#
# 122 :  # Total number of unread messages for all users
#
# 123 :  greetinglist = [profile['greeting'] for profile in profiles]
#
# 124 :  greetinglist
#
# 125 :
#
# 126 :  def get_digits(string):
#
# 127 :      new_string = ''
#
# 128 :      for s in string:
#
# 129 :          if s.isdigit():
#
# 130 :              new_string += s
#
# 131 :      return new_string
#
# 132 :
#
# 133 :  new = []
#
# 134 :  for g in greetinglist:
#
# 135 :      new.append(int(get_digits(g)))
#
# 136 :
#
# 137 :  sum(new)

# %%
# Write some python code to create a grocery list.
# Create a variable named grocery_list. It should be a list, and the elements in the list 
# should be a least 3 things that you need to buy from the grocery store.

grocery_list = ['Milk', 'Cheese', 'Eggs', 'Bacon']

# %%
# Create a function named make_grocery_list. When run, this function should write the 
# contents of the grocery_list variable to a file named my_grocery_list.txt.

def make_grocery_list(grocery_list):
    file_name = "my_grocery_list.txt"
    with open(file_name, "w") as f:
        for item in grocery_list:
            f.writelines(item + "\n")

# %%
make_grocery_list(grocery_list)

# %%
# Create a function named show_grocery_list. When run, it should read the items from 
# the text file and show each item on the grocery list.
def show_grocery_list():
    file_name = "my_grocery_list.txt"
    with open(file_name, "r") as f:
        contents = f.readlines()
        for item in contents:
            print(item)

# %%
show_grocery_list()
# Out:
# Milk
#
# Cheese
#
# Eggs
#
# Bacon

# %%
# Create a function named buy_item. It should accept the name of an item on the grocery list, 
# and remove that item from the list.
def buy_item(item, grocery_list):
    grocery_list.remove(item)
    make_grocery_list(grocery_list)

# %%
buy_item('Bacon', grocery_list)

# %%
show_grocery_list()
# Out:
# Milk
#
# Cheese
#
# Eggs
